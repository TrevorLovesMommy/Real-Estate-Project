# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format #turn off scientific notation
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#read unemployment data 
file = "resources/Local_Area_Unemployment_Statistics__LAUS___Annual_Average copy.csv" 
unemp_df = pd.read_csv(file) 
unemp_df.head()
# Out:
#   Area Type       Area Name  Year  Period  Labor Force  Employment  \
# 0    County  Alameda County  1990  Annual       677400      649900
# 1    County  Alameda County  1991  Annual       671800      635500
# 2    County  Alameda County  1992  Annual       677400      633100
# 3    County  Alameda County  1993  Annual       678100      633000
# 4    County  Alameda County  1994  Annual       679900      638200
#
#    Unemployment  Unemployment Rate Seasonally Adjusted (Y N) Status  \
# 0         27500               4.10                         N  Final
# 1         36300               5.40                         N  Final
# 2         44300               6.50                         N  Final
# 3         45100               6.60                         N  Final
# 4         41600               6.10                         N  Final
#
#    Unnamed: 10
# 0          nan
# 1          nan
# 2          nan
# 3          nan
# 4          nan

# %%
unemp_clean_df = unemp_df.loc[(unemp_df["Area Name"] == "Los Angeles County") | 
                            (unemp_df["Area Name"] == "Fresno County") |
                            (unemp_df["Area Name"] == "San Francisco County") |
                            (unemp_df["Area Name"] == "Shasta County"), :]

unemp_clean_df.head()
# Out:
#     Area Type      Area Name  Year  Period  Labor Force  Employment  \
# 406    County  Fresno County  1990  Annual       328700      290400
# 407    County  Fresno County  1991  Annual       336800      291800
# 408    County  Fresno County  1992  Annual       352600      298100
# 409    County  Fresno County  1993  Annual       361700      306000
# 410    County  Fresno County  1994  Annual       356200      305400
#
#      Unemployment  Unemployment Rate Seasonally Adjusted (Y N) Status  \
# 406         38300              11.60                         N  Final
# 407         45000              13.40                         N  Final
# 408         54600              15.50                         N  Final
# 409         55800              15.40                         N  Final
# 410         50700              14.20                         N  Final
#
#      Unnamed: 10
# 406          nan
# 407          nan
# 408          nan
# 409          nan
# 410          nan
